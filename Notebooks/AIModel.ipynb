# %%
import nltk
nltk.download('punkt')
nltk.download('omw-1.4')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\ASUS
# [nltk_data]     TUFF\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to C:\Users\ASUS
# [nltk_data]     TUFF\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\ASUS
# [nltk_data]     TUFF\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD
import random
from tensorflow.python.framework import ops
ops.reset_default_graph()

# %%
words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('C:/Users/ASUS TUFF/Desktop/Python_pj/AI_Assistant/Data/intents_All.json').read()
intents = json.loads(data_file)

# %%
for intent in intents['intents']:
    for pattern in intent['patterns']:
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        documents.append((w, intent['tag']))
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# %%
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
classes = sorted(list(set(classes)))
print (len(documents), "documents\n", documents, "\n")
print (len(classes), "classes\n", classes, "\n")
print (len(words), "unique lemmatized words\n", words, "\n")
pickle.dump(words,open('words.pkl','wb'))
pickle.dump(classes,open('classes.pkl','wb'))
# Out:
# 708 documents
#  [(['Hi'], 'greeting'), (['How', 'are', 'you', '?'], 'greeting'), (['Is', 'anyone', 'there', '?'], 'greeting'), (['Hello'], 'greeting'), (['Good', 'day'], 'greeting'), (['What', "'s", 'up'], 'greeting'), (['how', 'are', 'ya'], 'greeting'), (['heyy'], 'greeting'), (['whatsup'], 'greeting'), (['?', '?', '?', '?', '?', '?', '?', '?'], 'greeting'), (['cya'], 'goodbye'), (['see', 'you'], 'goodbye'), (['bye', 'bye'], 'goodbye'), (['See', 'you', 'later'], 'goodbye'), (['Goodbye'], 'goodbye'), (['I', 'am', 'Leaving'], 'goodbye'), (['Bye'], 'goodbye'), (['Have', 'a', 'Good', 'day'], 'goodbye'), (['talk', 'to', 'you', 'later'], 'goodbye'), (['ttyl'], 'goodbye'), (['i', 'got', 'to', 'go'], 'goodbye'), (['gtg'], 'goodbye'), (['what', 'is', 'the', 'name', 'of', 'your', 'developers'], 'creator'), (['what', 'is', 'the', 'name', 'of', 'your', 'creators'], 'creator'), (['what', 'is', 'the', 'name', 'of', 'the', 'developers'], 'creator'), (['what', 'is', 'the', 'name', 'of', 'the', 'creators'], 'creator'), (['who', 'created', 'you'], 'creator'), (['your', 'developers'], 'creator'), (['your', 'creators'], 'creator'), (['who', 'are', 'your', 'developers'], 'creator'), (['developers'], 'creator'), (['you', 'are', 'made', 'by'], 'creator'), (['you', 'are', 'made', 'by', 'whom'], 'creator'), (['who', 'created', 'you'], 'creator'), (['who', 'create', 'you'], 'creator'), (['who', 'make', 'you'], 'creator'), (['who', 'design'], 'creator'), (['creators'], 'creator'), (['who', 'made', 'you'], 'creator'), (['who', 'designed', 'you'], 'creator'), (['name'], 'name'), (['your', 'name'], 'name'), (['do', 'you', 'have', 'a', 'name'], 'name'), (['what', 'are', 'you', 'called'], 'name'), (['what', 'is', 'your', 'name'], 'name'), (['what', 'should', 'I', 'call', 'you'], 'name'), (['whats', 'your', 'name', '?'], 'name'), (['what', 'are', 'you'], 'name'), (['who', 'are', 'you'], 'name'), (['who', 'is', 'this'], 'name'), (['what', 'am', 'i', 'chatting', 'to'], 'name'), (['who', 'am', 'i', 'taking', 'to'], 'name'), (['what', 'are', 'you'], 'name'), (['timing', 'of', 'college'], 'hours'), (['what', 'is', 'college', 'timing'], 'hours'), (['working', 'days'], 'hours'), (['when', 'are', 'you', 'guys', 'open'], 'hours'), (['what', 'are', 'your', 'hours'], 'hours'), (['hours', 'of', 'operation'], 'hours'), (['when', 'is', 'the', 'college', 'open'], 'hours'), (['college', 'timing'], 'hours'), (['what', 'about', 'college', 'timing'], 'hours'), (['is', 'college', 'open', 'on', 'saturday'], 'hours'), (['tell', 'something', 'about', 'college', 'timing'], 'hours'), (['what', 'is', 'the', 'college', 'hours'], 'hours'), (['when', 'should', 'i', 'come', 'to', 'college'], 'hours'), (['when', 'should', 'i', 'attend', 'college'], 'hours'), (['what', 'is', 'my', 'college', 'time'], 'hours'), (['college', 'timing'], 'hours'), (['timing', 'college'], 'hours'), (['more', 'info'], 'number'), (['contact', 'info'], 'number'), (['how', 'to', 'contact', 'college'], 'number'), (['college', 'telephone', 'number'], 'number'), (['college', 'number'], 'number'), (['What', 'is', 'your', 'contact', 'no'], 'number'), (['Contact', 'number', '?'], 'number'), (['how', 'to', 'call', 'you'], 'number'), (['College', 'phone', 'no', '?'], 'number'), (['how', 'can', 'i', 'contact', 'you'], 'number'), (['Can', 'i', 'get', 'your', 'phone', 'number'], 'number'), (['how', 'can', 'i', 'call', 'you'], 'number'), (['phone', 'number'], 'number'), (['phone', 'no'], 'number'), (['call'], 'number'), (['list', 'of', 'courses'], 'course'), (['list', 'of', 'courses', 'offered'], 'course'), (['list', 'of', 'courses', 'offered', 'in'], 'course'), (['what', 'are', 'the', 'courses', 'offered', 'in', 'your', 'college', '?'], 'course'), (['courses', '?'], 'course'), (['courses', 'offered'], 'course'), (['courses', 'offered', 'in', '(', 'your', 'univrsity', '(', 'UNI', ')', 'name', ')'], 'course'), (['courses', 'you', 'offer'], 'course'), (['branches', '?'], 'course'), (['courses', 'available', 'at', 'UNI', '?'], 'course'), (['bra ...
#
# 113 classes
#  ['Abdonominal Pain', 'Abrasions', 'Broken Toe', 'Bruises', 'CPR', 'Chemical Burn', 'Choking', 'Cold', 'Cough', 'Cuts', 'Diarrhea', 'Drowning', 'Eye Injury', 'Fainting', 'Fever', 'Fracture', 'Frost bite', 'Gastrointestinal problems', 'Head Injury', 'Headache', 'Heat Exhaustion', 'Heat Stroke', 'Identity', 'Insect Bites', 'Movie', 'Nasal Congestion', 'Normal Bleeding', 'Poison', 'Pulled Muscle', 'Rash', 'Rectal bleeding', 'Skin problems', 'Sore Throat', 'Splinter', 'Sprains', 'Strains', 'Sun Burn', 'Teeth', 'Testicle Pain', 'Vertigo', 'Wound', 'activity', 'admission', 'age', 'animal bite', 'appreciate', 'canteen', 'college intake', 'committee', 'computerhod', 'contact', 'course', 'covid19', 'creator', 'cricket', 'datetime', 'document', 'event', 'exclaim', 'extchod', 'facilities', 'fees', 'floors', 'gender', 'goodbye', 'greeting', 'greetreply', 'haha', 'hod', 'hostel', 'hours', 'infrastructure', 'inspire', 'insult', 'ithod', 'jokes', 'karan', 'library', 'location', 'menu', 'my age', 'name', 'news', 'nicetty', 'no', 'nose bleed', 'number', 'options', 'placement', 'principal', 'programmer', 'ragging', 'random', 'riddle', 'salutaion', 'scholarship', 'seizure', 'sem', 'shop', 'snake bite', 'song', 'sports', 'stings', 'suggest', 'swear', 'syllabus', 'task', 'timer', 'uniform', 'vacation', 'vietnam', 'weather', 'whatsup']
#
# 447 unique lemmatized words
#  ["'m", "'s", '(', ')', '10', '19', 'a', 'abdonominal', 'about', 'abrasion', 'ac', 'active', 'activity', 'address', 'admision', 'admission', 'against', 'age', 'ai/ml', 'allergy', 'allotment', 'am', 'an', 'and', 'animal', 'antiragging', 'any', 'anyone', 'apply', 'are', 'as', 'ask', 'asshole', 'at', 'attend', 'automobile', 'available', 'average', 'awesome', 'bad', 'be', 'belong', 'belongs', 'best', 'better', 'between', 'big', 'bit', 'bitch', 'bite', 'bitten', 'bleed', 'bleeding', 'blocked', 'book', 'boy', 'branch', 'bring', 'broken', 'bruise', 'building', 'burn', 'buy', 'by', 'bye', 'cafetaria', 'call', 'called', 'campus', 'can', 'canteen', 'capacity', 'case', 'casuals', 'cause', 'ce', 'chatting', 'chemical', 'choke', 'choked', 'choking', 'civil', 'code', 'cold', 'college', 'come', 'committe', 'committee', 'comp', 'company', 'computer', 'conducted', 'congestion', 'contact', 'cough', 'could', 'country', 'course', 'covid', 'cpr', 'cream', 'create', 'created', 'creator', 'cricket', 'cure', 'current', 'cut', 'cya', 'date', 'day', 'design', 'designed', 'detail', 'developer', 'diagnose', 'diarrhea', 'different', 'distance', 'do', 'document', 'doe', 'dog', 'doing', 'done', 'dress', 'dresscode', 'drowned', 'drowning', 'due', 'dumb', 'during', 'each', 'eat', 'end', 'engineering', 'event', 'exam', 'exhausted', 'exhaustion', 'extc', 'eye', 'facility', 'faint', 'fainting', 'far', 'fee', 'feel', 'fever', 'few', 'fine', 'first', 'floor', 'food', 'for', 'fourth', 'fracture', 'from', 'frost', 'fuck', 'fucker', 'function', 'funny', 'game', 'gas', 'gastrointestinal', 'gender', 'get', 'girl', 'give', 'go', 'good', 'goodbye', 'got', 'great', 'gtg', 'guess', 'guy', 'haha', 'have', 'he', 'head', 'headache', 'heat', 'held', 'hell', 'hello', 'help', 'helpful', 'here', 'heyy', 'hi', 'history', 'hoang', 'hod', 'holiday', 'hostel', 'hot', 'hour', 'how', 'i', 'ice', 'id', 'idea', 'idiot', 'if', 'in', 'incident', 'india', 'info', 'information', 'infrastructure', 'injured', 'injury', 'insect', 'inspiration', 'inspires', 'intake', 'is', 'it', 'job', 'joke', 'junior', 'k', 'karan', 'know', 'last', 'later', 'latest', 'laugh', 'leaving', 'lecture', 'library', 'like', 'list', 'lmao', 'located', 'location', 'lol', 'long', 'love', 'made', 'make', 'malik', 'many', 'marry', 'match', 'max', 'maximum', 'me', 'mechanical', 'medicine', 'menu', 'might', 'mild', 'monekey', 'monkey', 'more', 'motivates', 'movie', 'much', 'muscle', 'my', 'name', 'nasal', 'need', 'needed', 'news', 'next', 'nice', 'no', 'non-ac', 'nope', 'nose', 'not', 'number', 'ny', 'of', 'offer', 'offered', 'office', 'ok', 'okay', 'okie', 'okk', 'old', 'on', 'open', 'operation', 'or', 'organised', 'package', 'pain', 'per', 'person', 'phone', 'pick', 'placement', 'please', 'poison', 'poisoned', 'poisoning', 'practice', 'predict', 'principal', 'problem', 'process', 'programmed', 'programmer', 'provide', 'provided', 'pulled', 'question', 'ragging', 'rash', 'reach', 'reccommend', 'recommend', 'recommendation', 'recruitment', 'rectal', 'remove', 'required', 'rid', 'riddle', 'rofl', 'room', 'sa', 'saturday', 'scar', 'schedule', 'scholarship', 'score', 'seat', 'second', 'see', 'seizure', 'sem', 'semester', 'servive', 'set', 'should', 'shut', 'size', 'skin', 'snake', 'some', 'someone', 'something', 'song', 'sore', 'splinter', 'sport', 'sprain', 'start', 'step', 'sting', 'strain', 'stroke', 'student', 'stundent', 'stupid', 'suggest', 'suggestion', 'sun', 'sup', 'support', 'surface', 'syllabus', 'take', 'taken', 'taking', 'talk', 'talking', 'tall', 'technology', 'teeth', 'telephone', 'tell', 'temperature', 'ten', 'testicle', 'thank', 'thanks', 'that', 'thats', 'the', 'there', 'these', 'thing', 'think', 'third', 'this', 'throat', 'time', 'timer', 'timetable', 'timing', 'to', 'today', 'toe', 'top', 'treat', 'truong', 'ttyl', 'u', 'uni', 'uniform', 'univrsity', 'up', 'upto', 'use', 'useless', 'vacation', 'variety', 'vertigo', 'visit', 'wa', 'watch', 'wazzup', 'we', 'wear', 'weather', 'well', 'were', 'what', 'whats', 'wh ...

# %%
training = []
output_empty = [0] * len(classes)
for doc in documents:
    bag = []
    pattern_words = doc[0]
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)
    
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    
    training.append([bag, output_row])

random.shuffle(training)
training = np.asarray(training, dtype="object")
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")
# Out:
# Training data created

# %%
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# %%
adam= tf.keras.optimizers.Adam(0.001)
model.compile(optimizer=adam,loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               57344
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_3 (Dense)             (None, 113)               7345
#
# =================================================================
# Total params: 77,105
# Trainable params: 77,105
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
# Out:
# Epoch 1/200
# 142/142 [==============================] - 7s 6ms/step - loss: 4.6884 - accuracy: 0.0282
# Epoch 2/200
# 142/142 [==============================] - 1s 6ms/step - loss: 4.3745 - accuracy: 0.0565
# Epoch 3/200
# 142/142 [==============================] - 1s 5ms/step - loss: 4.0645 - accuracy: 0.0946
# Epoch 4/200
# 142/142 [==============================] - 1s 4ms/step - loss: 3.7731 - accuracy: 0.1130
# Epoch 5/200
# 142/142 [==============================] - 1s 4ms/step - loss: 3.4792 - accuracy: 0.2006
# Epoch 6/200
# 142/142 [==============================] - 1s 4ms/step - loss: 3.2399 - accuracy: 0.2316
# Epoch 7/200
# 142/142 [==============================] - 1s 4ms/step - loss: 2.9903 - accuracy: 0.2895
# Epoch 8/200
# 142/142 [==============================] - 1s 4ms/step - loss: 2.7438 - accuracy: 0.3616
# Epoch 9/200
# 142/142 [==============================] - 1s 4ms/step - loss: 2.5721 - accuracy: 0.3630
# Epoch 10/200
# 142/142 [==============================] - 1s 5ms/step - loss: 2.3612 - accuracy: 0.4068
# Epoch 11/200
# 142/142 [==============================] - 1s 4ms/step - loss: 2.2132 - accuracy: 0.4054
# Epoch 12/200
# 142/142 [==============================] - 1s 5ms/step - loss: 2.0095 - accuracy: 0.4972
# Epoch 13/200
# 142/142 [==============================] - 1s 4ms/step - loss: 1.8206 - accuracy: 0.5028
# Epoch 14/200
# 142/142 [==============================] - 1s 4ms/step - loss: 1.7754 - accuracy: 0.5381
# Epoch 15/200
# 142/142 [==============================] - 1s 4ms/step - loss: 1.6233 - accuracy: 0.5692
# Epoch 16/200
# 142/142 [==============================] - 1s 5ms/step - loss: 1.4936 - accuracy: 0.5847
# Epoch 17/200
# 142/142 [==============================] - 1s 4ms/step - loss: 1.3894 - accuracy: 0.6130
# Epoch 18/200
# 142/142 [==============================] - 1s 4ms/step - loss: 1.3053 - accuracy: 0.6398
# Epoch 19/200
# 142/142 [==============================] - 1s 4ms/step - loss: 1.2951 - accuracy: 0.6172
# Epoch 20/200
# 142/142 [==============================] - 1s 4ms/step - loss: 1.2194 - accuracy: 0.6695
# Epoch 21/200
# 142/142 [==============================] - 1s 4ms/step - loss: 1.1570 - accuracy: 0.6610
# Epoch 22/200
# 142/142 [==============================] - 1s 4ms/step - loss: 1.0819 - accuracy: 0.6907
# Epoch 23/200
# 142/142 [==============================] - 1s 4ms/step - loss: 1.0561 - accuracy: 0.6822
# Epoch 24/200
# 142/142 [==============================] - 1s 5ms/step - loss: 1.0191 - accuracy: 0.6949
# Epoch 25/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.9677 - accuracy: 0.7189
# Epoch 26/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.9212 - accuracy: 0.7246
# Epoch 27/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.8807 - accuracy: 0.7316
# Epoch 28/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.8463 - accuracy: 0.7472
# Epoch 29/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.7901 - accuracy: 0.7881
# Epoch 30/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.7793 - accuracy: 0.7585
# Epoch 31/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.7383 - accuracy: 0.7895
# Epoch 32/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.7706 - accuracy: 0.7585
# Epoch 33/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.7369 - accuracy: 0.7938
# Epoch 34/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.6132 - accuracy: 0.8107
# Epoch 35/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.6957 - accuracy: 0.7839
# Epoch 36/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.6192 - accuracy: 0.8065
# Epoch 37/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.6734 - accuracy: 0.8008
# Epoch 38/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.6637 - accuracy: 0.8065
# Epoch 39/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.5819 - accuracy: 0.8263
# Epoch 40/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.6244 - accuracy: 0.8079
# Epoch 41/200
# 142/142 [==============================] - 1s 4ms/step - loss: 0.6272 - accuracy: 0.8234
# Epoch 42/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.5674 - accuracy: 0.8121
# Epoch 43/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.5295 - accuracy: 0.8404
# Epoch 44/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.5200 - accuracy: 0.8404
# Epoch 45/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.5430 - accuracy: 0.8390
# Epoch 46/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.4997 - accuracy: 0.8234
# Epoch 47/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.5714 - accuracy: 0.8263
# Epoch 48/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.5261 - accuracy: 0.8277
# Epoch 49/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.4405 - accuracy: 0.8701
# Epoch 50/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.4717 - accuracy: 0.8658
# Epoch 51/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.4554 - accuracy: 0.8630
# Epoch 52/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.4298 - accuracy: 0.8630
# Epoch 53/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.4637 - accuracy: 0.8602
# Epoch 54/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.4498 - accuracy: 0.8503
# Epoch 55/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.4220 - accuracy: 0.8686
# Epoch 56/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.4484 - accuracy: 0.8503
# Epoch 57/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.3863 - accuracy: 0.8701
# Epoch 58/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.4335 - accuracy: 0.8573
# Epoch 59/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.4850 - accuracy: 0.8475
# Epoch 60/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.4251 - accuracy: 0.8588
# Epoch 61/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.3940 - accuracy: 0.8743
# Epoch 62/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.3949 - accuracy: 0.8729
# Epoch 63/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.4249 - accuracy: 0.8545
# Epoch 64/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.3871 - accuracy: 0.8743
# Epoch 65/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.4605 - accuracy: 0.8503
# Epoch 66/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.3378 - accuracy: 0.8856
# Epoch 67/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.3372 - accuracy: 0.8743
# Epoch 68/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.3432 - accuracy: 0.8870
# Epoch 69/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.3460 - accuracy: 0.8842
# Epoch 70/200
# 142/142 [==============================] - 1s 7ms/step - loss: 0.3600 - accuracy: 0.8799
# Epoch 71/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.4277 - accuracy: 0.8588
# Epoch 72/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.3799 - accuracy: 0.8898
# Epoch 73/200
# 142/142 [==============================] - 1s 7ms/step - loss: 0.3322 - accuracy: 0.8856
# Epoch 74/200
# 142/142 [==============================] - 1s 7ms/step - loss: 0.2842 - accuracy: 0.9040
# Epoch 75/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.3523 - accuracy: 0.8828
# Epoch 76/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.4162 - accuracy: 0.8644
# Epoch 77/200
# 142/142 [==============================] - 1s 7ms/step - loss: 0.3138 - accuracy: 0.8941
# Epoch 78/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.3587 - accuracy: 0.8927
# Epoch 79/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.3678 - accuracy: 0.8771
# Epoch 80/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.3434 - accuracy: 0.8941
# Epoch 81/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.3691 - accuracy: 0.8701
# Epoch 82/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.3607 - accuracy: 0.8799
# Epoch 83/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.3692 - accuracy: 0.8757
# Epoch 84/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.3192 - accuracy: 0.8941
# Epoch 85/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.2988 - accuracy: 0.8983
# Epoch 86/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2796 - accuracy: 0.9040
# Epoch 87/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2730 - accuracy: 0.9124
# Epoch 88/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.3202 - accuracy: 0.8856
# Epoch 89/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.3125 - accuracy: 0.8969
# Epoch 90/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.3088 - accuracy: 0.8969
# Epoch 91/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.2658 - accuracy: 0.9153
# Epoch 92/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.3742 - accuracy: 0.8799
# Epoch 93/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2955 - accuracy: 0.8912
# Epoch 94/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.3215 - accuracy: 0.8983
# Epoch 95/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.3322 - accuracy: 0.8955
# Epoch 96/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.3170 - accuracy: 0.9011
# Epoch 97/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.3488 - accuracy: 0.8828
# Epoch 98/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2876 - accuracy: 0.9040
# Epoch 99/200
# 142/142 [==============================] - 1s 7ms/step - loss: 0.3146 - accuracy: 0.8884
# Epoch 100/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.3677 - accuracy: 0.8898
# Epoch 101/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.3427 - accuracy: 0.8785
# Epoch 102/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.3109 - accuracy: 0.9040
# Epoch 103/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.2742 - accuracy: 0.9096
# Epoch 104/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2915 - accuracy: 0.9096
# Epoch 105/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.2611 - accuracy: 0.9068
# Epoch 106/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.3018 - accuracy: 0.8941
# Epoch 107/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.3714 - accuracy: 0.8927
# Epoch 108/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.3196 - accuracy: 0.8870
# Epoch 109/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.3048 - accuracy: 0.8983
# Epoch 110/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2820 - accuracy: 0.9153
# Epoch 111/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2823 - accuracy: 0.8969
# Epoch 112/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2897 - accuracy: 0.9068
# Epoch 113/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2485 - accuracy: 0.9068
# Epoch 114/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2827 - accuracy: 0.9040
# Epoch 115/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2079 - accuracy: 0.9294
# Epoch 116/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2887 - accuracy: 0.9025
# Epoch 117/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.2466 - accuracy: 0.9251
# Epoch 118/200
# 142/142 [==============================] - 1s 7ms/step - loss: 0.2355 - accuracy: 0.9181
# Epoch 119/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.3269 - accuracy: 0.8870
# Epoch 120/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.2827 - accuracy: 0.9110
# Epoch 121/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.3034 - accuracy: 0.9096
# Epoch 122/200
# 142/142 [==============================] - 1s 7ms/step - loss: 0.2792 - accuracy: 0.8941
# Epoch 123/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2892 - accuracy: 0.9153
# Epoch 124/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.3157 - accuracy: 0.8983
# Epoch 125/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.2636 - accuracy: 0.9011
# Epoch 126/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.2279 - accuracy: 0.9251
# Epoch 127/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.2635 - accuracy: 0.9251
# Epoch 128/200
# 142/142 [==============================] - 1s 7ms/step - loss: 0.2606 - accuracy: 0.9025
# Epoch 129/200
# 142/142 [==============================] - 1s 8ms/step - loss: 0.2735 - accuracy: 0.9138
# Epoch 130/200
# 142/142 [==============================] - 1s 7ms/step - loss: 0.2724 - accuracy: 0.9025
# Epoch 131/200
# 142/142 [==============================] - 1s 9ms/step - loss: 0.2120 - accuracy: 0.9379
# Epoch 132/200
# 142/142 [==============================] - 1s 9ms/step - loss: 0.2159 - accuracy: 0.9209
# Epoch 133/200
# 142/142 [==============================] - 1s 7ms/step - loss: 0.3085 - accuracy: 0.8898
# Epoch 134/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.2247 - accuracy: 0.9223
# Epoch 135/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2728 - accuracy: 0.9124
# Epoch 136/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2675 - accuracy: 0.9025
# Epoch 137/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.3036 - accuracy: 0.9082
# Epoch 138/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2635 - accuracy: 0.9138
# Epoch 139/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2847 - accuracy: 0.8997
# Epoch 140/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2790 - accuracy: 0.9082
# Epoch 141/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2458 - accuracy: 0.9124
# Epoch 142/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2343 - accuracy: 0.9153
# Epoch 143/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2217 - accuracy: 0.9280
# Epoch 144/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2606 - accuracy: 0.9209
# Epoch 145/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2663 - accuracy: 0.9195
# Epoch 146/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2006 - accuracy: 0.9336
# Epoch 147/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2365 - accuracy: 0.9223
# Epoch 148/200
# 142/142 [==============================] - 1s 7ms/step - loss: 0.2200 - accuracy: 0.9336
# Epoch 149/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.2307 - accuracy: 0.9181
# Epoch 150/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.2101 - accuracy: 0.9251
# Epoch 151/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.2616 - accuracy: 0.9209
# Epoch 152/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2658 - accuracy: 0.9096
# Epoch 153/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.2831 - accuracy: 0.9011
# Epoch 154/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.2164 - accuracy: 0.9209
# Epoch 155/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.2473 - accuracy: 0.9096
# Epoch 156/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2533 - accuracy: 0.9223
# Epoch 157/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.2235 - accuracy: 0.9294
# Epoch 158/200
# 142/142 [==============================] - 1s 9ms/step - loss: 0.2727 - accuracy: 0.9251
# Epoch 159/200
# 142/142 [==============================] - 1s 7ms/step - loss: 0.1986 - accuracy: 0.9280
# Epoch 160/200
# 142/142 [==============================] - 1s 8ms/step - loss: 0.2324 - accuracy: 0.9223
# Epoch 161/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.2349 - accuracy: 0.9280
# Epoch 162/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.2318 - accuracy: 0.9280
# Epoch 163/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.2656 - accuracy: 0.9068
# Epoch 164/200
# 142/142 [==============================] - 1s 7ms/step - loss: 0.2474 - accuracy: 0.9138
# Epoch 165/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2411 - accuracy: 0.9138
# Epoch 166/200
# 142/142 [==============================] - 1s 7ms/step - loss: 0.2289 - accuracy: 0.9237
# Epoch 167/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.2701 - accuracy: 0.9096
# Epoch 168/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2153 - accuracy: 0.9209
# Epoch 169/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2177 - accuracy: 0.9251
# Epoch 170/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2386 - accuracy: 0.9209
# Epoch 171/200
# 142/142 [==============================] - 1s 7ms/step - loss: 0.2309 - accuracy: 0.9223
# Epoch 172/200
# 142/142 [==============================] - 1s 6ms/step - loss: 0.1962 - accuracy: 0.9195
# Epoch 173/200
# 142/142 [==============================] - 1s 7ms/step - loss: 0.2566 - accuracy: 0.9040
# Epoch 174/200
# 142/142 [==============================] - 1s 8ms/step - loss: 0.2021 - accuracy: 0.9322
# Epoch 175/200
# 142/142 [==============================] - 1s 7ms/step - loss: 0.2018 - accuracy: 0.9266
# Epoch 176/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.1847 - accuracy: 0.9364
# Epoch 177/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2397 - accuracy: 0.9237
# Epoch 178/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2145 - accuracy: 0.9336
# Epoch 179/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2667 - accuracy: 0.9251
# Epoch 180/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2275 - accuracy: 0.9237
# Epoch 181/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2224 - accuracy: 0.9138
# Epoch 182/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2299 - accuracy: 0.9153
# Epoch 183/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2857 - accuracy: 0.8997
# Epoch 184/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2327 - accuracy: 0.9167
# Epoch 185/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.1933 - accuracy: 0.9167
# Epoch 186/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2074 - accuracy: 0.9209
# Epoch 187/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2107 - accuracy: 0.9237
# Epoch 188/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.1943 - accuracy: 0.9195
# Epoch 189/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2143 - accuracy: 0.9237
# Epoch 190/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.1969 - accuracy: 0.9294
# Epoch 191/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2110 - accuracy: 0.9251
# Epoch 192/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2388 - accuracy: 0.9110
# Epoch 193/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.1798 - accuracy: 0.9350
# Epoch 194/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2091 - accuracy: 0.9294
# Epoch 195/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2188 - accuracy: 0.9322
# Epoch 196/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.1652 - accuracy: 0.9435
# Epoch 197/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2160 - accuracy: 0.9251
# Epoch 198/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2183 - accuracy: 0.9294
# Epoch 199/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2073 - accuracy: 0.9294
# Epoch 200/200
# 142/142 [==============================] - 1s 5ms/step - loss: 0.2370 - accuracy: 0.9195

# %%
model.save('chatbot_model.h5', hist)

# %%
with open('C:/Users/ASUS TUFF/Desktop/Python_pj/AI_Assistant/Data/intents_All.json', 'r') as json_file:
    data = json.load(json_file)
with open('ChatbotData.pkl', 'wb') as pickle_file:
    pickle.dump(data, pickle_file)

# %%
from keras.models import load_model
model = load_model('chatbot_model.h5')

# %%
with open('ChatbotData.pkl', 'rb') as pickle_file:
    intents = pickle.load(pickle_file)

# %%
words = pickle.load(open('words.pkl','rb'))

classes = pickle.load(open('classes.pkl','rb'))

# %%
def clean_up_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]

    return sentence_words

def bow(sentence, words, show_details=True):
    sentence_words = clean_up_sentence(sentence)
    bag = [0]*len(words)

    for s in sentence_words:  
        for i,w in enumerate(words):
            if w == s: 
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % w)
    return(np.array(bag))

def predict_class(sentence, model):
    p = bow(sentence, words,show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.1

    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]

    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []

    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})

    return return_list

def getResponse(ints, intents_json):
    tag = ints[0]['intent']

    list_of_intents = intents_json['intents']

    for i in list_of_intents:
        if(i['tag']== tag):
            result = random.choice(i['responses'])
            break
    return result

def chatbot_response(text): 
    ints = predict_class(text, model)
    res = getResponse(ints, intents)
    return res

# %%
start = True

while start:
    query = input('Enter Message:')
    if query in ['quit','exit','bye']:
        
        start = False
        continue
    try:
        res = chatbot_response(query)
        print(res)
    except:
        print('You may need to rephrase your question.')
# Out:
# 1/1 [==============================] - 0s 314ms/step
# Definitely, but can you give me a sentence to help me figure it out?
